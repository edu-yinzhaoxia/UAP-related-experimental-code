# %% [markdown]
# ## ImageNet UAP - Evaluation
# We show evaluations on the following:
# 1. Evaluation on clean datasets (train, test)
# 2. White-box attacks (untargeted, targeted)
# 3. Transfer attacks

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import torch
import imageio
sys.path.append(os.path.realpath('..'))

from utils import loader_imgnet, model_imgnet, evaluate, save_image3

dir_data = 'F:/org/'
dir_uap = './uaps/imagenet/'
loader = loader_imgnet(dir_data, 10000, 5) # evaluate on 10,000 validation images

# %%
# load model
model = model_imgnet('resnet50')
# Out:
# Model loading complete.

# %% [markdown]
# ## 1. Clean

# %%
_, _, _, _, outputs, labels = evaluate(model, loader, uap = None)
print('Accuracy:', sum(outputs == labels) / len(labels))
# Out:
# Accuracy: 0.8485

# %% [markdown]
# ## 2.1 Untargeted UAP

# %%
# load pattern
uap = torch.load(dir_uap + 'sgd-resnet50-eps10.pth')

# %%
# visualize
uap_max = torch.max(uap)
plt.axis('off')
#plt.imshow(np.transpose(((uap / uap_max) + 1) / 2, (1, 2, 0)))
ae1 = np.transpose(((uap / uap_max) + 1) / 2, (1, 2, 0))
plt.imshow(ae1)
save_image3("sgd-resnet50-eps10.png", uap)

# %%
# evaluate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-0af7c015e29b> in <module>
#       1 # evaluate
# ----> 2 _, _, _, _, outputs, labels = evaluate(model, loader, uap = uap)
#       3 print('Accuracy:', sum(outputs == labels) / len(labels))
#
# f:\coding\CW (2)\uap\utils.py in evaluate(model, loader, uap, n)
#     194                 perturbed = torch.clamp((x_val + uap).cuda(), 0, 1) # clamp to [0, 1]
#     195
# --> 196                 print(perturbed)
#     197                 plt.imshow(np.transpose(perturbed,(1,2,0)))
#     198                 plt.savefig("111.png")
#
# E:\jupyter\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     302
#     303             raise AttributeError("module {!r} has no attribute "
# --> 304                                  "{!r}".format(__name__, attr))
#     305
#     306         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'perturbed'

# %% [markdown]
# ## 2.2 Targeted UAP
# Target: 859 Toaster

# %%
# load pattern
y_target = 859
uap = torch.load(dir_uap + 'sgd-tgt%i-resnet50-eps10.pth' % y_target)

# %%
# visualize
uap_max = torch.max(uap)
plt.axis('off')
plt.imshow(np.transpose(((uap / uap_max) + 1) / 2, (1, 2, 0)))
plt.savefig('sgd-tgt%i-resnet50-eps10.png' % y_target, format='png', bbox_inches='tight')

# %%
# evaluate
_, _, _, _, outputs, labels = evaluate(model, loader, uap = uap)
print('Accuracy:', sum(outputs == labels) / len(labels))
print('Targeted success rate:', sum(outputs == y_target) / len(labels))
# Out:
# Accuracy: 0.1869
# Targeted success rate: 0.651

# %% [markdown]
# ## 3.1 Transfer attack from SIN

# %%
# load pattern
uap = torch.load(dir_uap + 'sgd-resnet50_SIN-eps10.pth')

# %%
# visualize
uap_max = torch.max(uap)
plt.imshow(np.transpose(((uap / uap_max) + 1) / 2, (1, 2, 0)))

# %%
# evaluate
_, _, _, _, outputs, labels = evaluate(model, loader, uap = uap)
print('Accuracy:', sum(outputs == labels) / len(labels))
# Out:
# Accuracy: 0.4336

# %% [markdown]
# ## 3.2 Transfer attack from IN+SIN

# %%
# load pattern
uap = torch.load(dir_uap + 'sgd-resnet50_SIN-IN-eps10.pth')

# %%
# visualize
uap_max = torch.max(uap)
plt.imshow(np.transpose(((uap / uap_max) + 1) / 2, (1, 2, 0)))

# %%
# evaluate
_, _, _, _, outputs, labels = evaluate(model, loader, uap = uap)
print('Accuracy:', sum(outputs == labels) / len(labels))
# Out:
# Accuracy: 0.1296

# %% [markdown]
# ## 3.3 Transfer attack from VGG-16

# %%
# load pattern
uap = torch.load(dir_uap + 'sgd-vgg16-eps10.pth')

# %%
# visualize
uap_max = torch.max(uap)
plt.imshow(np.transpose(((uap / uap_max) + 1) / 2, (1, 2, 0)))

# %%
# evaluate
_, _, _, _, outputs, labels = evaluate(model, loader, uap = uap)
print('Accuracy:', sum(outputs == labels) / len(labels))
# Out:
# Accuracy: 0.513
